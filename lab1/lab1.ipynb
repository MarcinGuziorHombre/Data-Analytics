# %%
import pandas as pd
import numpy as np
import seaborn as sns
import bokeh
import pandas
import numpy
import scipy
import matplotlib. pyplot as plt

# %matplotlib inline
sns.set()
DATA_SRC = "Data1.csv"

# %%
#import data to csv_file.

df = pd.read_csv(DATA_SRC, index_col=0)
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5    theta_6
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908   0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288   1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351   2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518   1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092   1.742433
# ...              ...       ...       ...       ...       ...        ...
# 2019-12-27 -1.520171 -1.128868  1.108275  0.936817  0.948045  11.755980
# 2019-12-28  0.338910 -3.178251  1.484579  1.051123  1.025288  11.397092
# 2019-12-29  0.263781  0.045725 -0.112476  0.823782  0.914111  10.918941
# 2019-12-30 -0.425098 -1.002701 -0.834294  0.850904  0.801977  11.140722
# 2019-12-31  0.848302  3.510521 -0.280626  0.967050  1.091803  11.989975
#
# [1095 rows x 6 columns]

# %%
#plot all columns as timestamp

df.plot()

# %%
#histogram as sns

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b73a4be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b7357df0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b737d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b7326ee0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b72db760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b7305fa0>]],
#       dtype=object)

# %%
#create df_melt

df_melt = df.melt(value_vars=df.columns.unique().to_list())

# %%
#create histogram for each theta

g = sns.FacetGrid(df_melt, col='variable', sharex=False)
g.map(plt.hist, 'value')

# %%
#plot kde for each theta
df.plot.kde()

# %%
#homework

#prepare dataset
df_h = df[df.columns.unique().to_list()[0:4]]
only_in_2018 = (df_h.index > '2018-01-01 00:00:00') & (df_h.index < '2019-01-01 00:00:00')
df_h = df_h.loc[only_in_2018]

# %%
#plot all data

df_h.plot()

# %%
#plot all histograms

df_h.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b6604f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b65a37f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b6556e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3b657d670>]],
#       dtype=object)

# %%
#plot all histograms on seaborn FaceGrid

df_h_melt = df.melt(value_vars = df_h.columns.unique().to_list())
g = sns.FacetGrid(df_h_melt, col='variable', sharex=False)
g.map(plt.hist, 'value')

# %%
#plot all kde

df_h.plot.kde()
